# %% [markdown]
# <a href="https://colab.research.google.com/github/eshaanrathi2/soil-analysis/blob/master/eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Mounted my google drive, where my files have been uploaded
#
# here are the links of the files:
#
# csv file : https://drive.google.com/open?id=1wxUzOSaoQYW_4XTKRSZ2vz1c6FIzU4SO
#
# meta data : https://drive.google.com/open?id=1sSKjvhfORW7iw0XV5xl0zl0Pus2UUtcl
#
# xlsx file : https://drive.google.com/open?id=1eyN0LMaijwuy_cxKhSREWhKOwi7uMheB
#
# Original dataset source link : https://data.world/agriculture/crop-production

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas as pd

# %% [markdown]
# Now I will be Reading the file "final2.csv" which has our data of all sheets combined

# %%
df = pd.read_csv("/content/drive/My Drive/final2.csv")

# %%
df
# Out:
#        Unnamed: 0  area_code                       area  ...  y2013f     y2014  y2014f
# 0               0          4                    Algeria  ...     NaN   48222.0     NaN
# 1               1          4                    Algeria  ...      Fc   13443.0      Fc
# 2               2          4                    Algeria  ...     NaN   64827.0     NaN
# 3               3          4                    Algeria  ...     NaN   40418.0     NaN
# 4               4          4                    Algeria  ...      Fc  114507.0      Fc
# ...           ...        ...                        ...  ...     ...       ...     ...
# 41756       41756        243  Wallis and Futuna Islands  ...       A       NaN     NaN
# 41757       41757        243  Wallis and Futuna Islands  ...       A     258.0       A
# 41758       41758        243  Wallis and Futuna Islands  ...      Fc   26167.0      Fc
# 41759       41759        243  Wallis and Futuna Islands  ...       A     676.0       A
# ...

# %%
df.shape
# Out:
# (41761, 116)

# %% [markdown]
# **Now we will be observing metadata:**

# %%
df2 = pd.read_excel()

# %% [markdown]
# # New Section

# %% [markdown]
# **Now I will be dropping column number 0, 2, 4, 6 as they don't have impact on our target values i.e. production of various years**

# %%
df.drop(df.columns[[0,2,4,6]], axis = 1, inplace = True)

# %% [markdown]
# **Now remaining variables/columns are :**

# %%
df.columns
# Out:
# Index(['area_code', 'item_code', 'element_code', 'unit', 'y1961', 'y1961f',
#        'y1962', 'y1962f', 'y1963', 'y1963f',
#        ...
#        'y2010', 'y2010f', 'y2011', 'y2011f', 'y2012', 'y2012f', 'y2013',
#        'y2013f', 'y2014', 'y2014f'],
#       dtype='object', length=112)

# %% [markdown]
# **Shape of our dataframe after deletion of columns :**

# %%
df.shape
# Out:
# (11700, 112)

# %% [markdown]
# **Dropping duplicate rows**

# %%
duplicate_rows_df = df[df.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (0, 112)

# %% [markdown]
# **So, no duplicate rows are found in my dataset.**
#
# **Now we look for missing values, if found we will drop them**

# %%
df.count()
# Out:
# area_code       41761
# item_code       41761
# element_code    41761
# unit            41761
# y1961           26893
#                 ...
# y2012f          28571
# y2013           38271
# y2013f          28756
# y2014           34829
# y2014f          25837
# Length: 112, dtype: int64

# %%
df = df.dropna()
df.count()
# Out:
# area_code       11700
# item_code       11700
# element_code    11700
# unit            11700
# y1961           11700
#                 ...
# y2012f          11700
# y2013           11700
# y2013f          11700
# y2014           11700
# y2014f          11700
# Length: 112, dtype: int64

# %%
df.shape
# Out:
# (11700, 112)

# %% [markdown]
# **Number of rows have drastically reduced to nearly 25% wrt prior removing null values**

# %% [markdown]
# **Now, we will be making some plots and hence imported pyplot and used seaborn for visualisation**

# %%
import seaborn as sb
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(112,112))
matrix = df.corr()
sb.heatmap(matrix,cmap="BrBG",annot=True)
matrix
# Out:
#               area_code  item_code  element_code  ...     y2012     y2013     y2014
# area_code      1.000000  -0.004121     -0.000523  ... -0.019261 -0.017030 -0.016531
# item_code     -0.004121   1.000000     -0.018252  ...  0.074792  0.074171  0.074329
# element_code  -0.000523  -0.018252      1.000000  ...  0.073005  0.073467  0.073905
# y1961         -0.000409   0.091982      0.034100  ...  0.785388  0.803679  0.801451
# y1962         -0.002807   0.093522      0.037531  ...  0.787636  0.805574  0.802588
# y1963         -0.001908   0.092196      0.038553  ...  0.786813  0.806497  0.803164
# y1964         -0.004180   0.094031      0.038618  ...  0.791653  0.807005  0.803624
# y1965         -0.001912   0.090736      0.039795  ...  0.794516  0.814303  0.811143
# y1966         -0.003690   0.090057      0.041534  ...  0.798319  0.816788  0.813072
# y1967         -0.000993   0.088183      0.043086  ...  0.796491  0.817338  0.814279
# ...

# %%
df.describe()
# Out:
#           area_code     item_code  ...         y2013         y2014
# count  11700.000000  11700.000000  ...  1.170000e+04  1.170000e+04
# mean     121.342991   1041.486838  ...  1.177177e+06  1.199285e+06
# std       71.225427    714.747762  ...  1.387497e+07  1.413081e+07
# min        2.000000     15.000000  ...  0.000000e+00  0.000000e+00
# 25%       58.000000    388.000000  ...  1.035950e+04  1.015675e+04
# 50%      117.000000    773.000000  ...  5.030450e+04  5.040200e+04
# 75%      181.000000   1753.000000  ...  1.850815e+05  1.847588e+05
# max      251.000000   1841.000000  ...  5.807035e+08  5.961096e+08
#
# [8 rows x 57 columns]

# %% [markdown]
# **Insights of the Notebook :**

# %% [markdown]
# We are working on agricultural data set found on the link :https://data.world/agriculture/crop-production
#
# It contains agricultural data of various countries around the globe (in specific continent, which we have clubbed together). Data for eg harvest India in the year 2001 for a particular food, say apple can be found in the data.
#
# The visible dependant variabales were yearwise production.
# It had various redundancies and anomalies which we have cleaned. Like there were missing values in the data, and had we trained an ML model over it, it would have been fatal. we also checked for duplicate entries in the datset but found none. We removd irrelevant variables, w.r.t to target or dependant variables(yearwise production) and made the dataframe more readable. We also plotted a correlation matrix to gain better insigths about the data.
